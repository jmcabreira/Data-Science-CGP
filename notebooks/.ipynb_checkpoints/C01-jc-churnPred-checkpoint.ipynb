# %% [markdown]
# # <center> Churn Prediction <center/>

# %% [markdown]
# # Premises

# %% [markdown]
# * The bank revenue comes from clients transactions
# * We will estimate the average revenue as:
#     * 15% of the client salary, if the their salary is lower than the mean salary of all the bank clients
#     * 20% of the client salary, if the their salary is greater or equal the mean salary of all the bank clients
#
# <br>

# %% [markdown]
# # The Business Problem:
# * Anuanly, part of the bank clients do not renew their contract
# * The goal is to predict which clients are more likely to leave ( do not renew their contract)

# %% [markdown]
# <br>

# %% [markdown]
# # 0.0 Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
from IPython.display         import Image
from IPython.core.display    import HTML
from sklearn.model_selection import train_test_split
from sklearn.model_selection import learning_curve
from sklearn.linear_model    import LogisticRegression
from sklearn.ensemble        import RandomForestClassifier,AdaBoostClassifier,GradientBoostingClassifier,BaggingClassifier
from sklearn.naive_bayes     import GaussianNB 
from sklearn.model_selection import  KFold, cross_val_score
from xgboost                 import XGBClassifier
#from sklearn.preprocessing import OneHotEncoder

# %% [markdown]
# ## 0.1 Functions

# %%
def descriptive_sts(num_attributes):
    # Central Tedency - mean, median
    ct1 = pd.DataFrame(num_attributes.apply(np.mean)).T
    ct2 = pd.DataFrame(num_attributes.apply(np.median)).T

    #Dispersion - str,min, max,range,skew,kurtosis
    d1 = pd.DataFrame(num_attributes.apply(np.std)).T
    d2 = pd.DataFrame(num_attributes.apply(min)).T
    d3 = pd.DataFrame(num_attributes.apply(max)).T
    d4 = pd.DataFrame(num_attributes.apply(lambda x : x.max() - x.min())).T
    d5 = pd.DataFrame(num_attributes.apply(lambda x : x.skew())).T
    d6 = pd.DataFrame(num_attributes.apply(lambda x : x.kurtosis())).T

    #Contatenate
    m = pd.concat([d2,d3,d4,ct1,ct2,d1,d5,d6]).T.reset_index()
    m.columns = ['attributes', 'min', 'max', 'range','mean','median', 'std','skew','kurtosis']
    return m

def jupyter_settings():
    # %matplotlib inline
    # %pylab inline
    
    plt.style.use( 'bmh' )
    plt.rcParams['figure.figsize'] = [25, 12]
    plt.rcParams['font.size'] = 24
    
    display( HTML( '<style>.container { width:100% !important; }</style>') )
    pd.options.display.max_columns = None
    pd.options.display.max_rows = None
    pd.set_option( 'display.expand_frame_repr', False )
    
    sns.set()
    

def box_dist_plots(target_col, value_col, df, bins = 10 ):
    plt.subplot(2,2,1)
    sns.boxplot(x = target_col, y = value_col, data = df)

    plt.subplot(2,2,2)
    aux = df[[ value_col]]
    sns.histplot(aux)

    plt.subplot(2,2,3)
    aux = df.loc[df[target_col] == 1 ,value_col]
    sns.histplot(aux, fill = False,element="step",bins = 10, color = 'red')

    aux = df.loc[df[target_col] == 0 , value_col]
    sns.histplot(aux, fill = False, element="step",bins = 10, color = 'green')
    plt.legend(title=value_col, labels=['1', '0'], )
    plt.title(value_col);

    plt.subplot(2,2,4)
    aux = df.loc[df[target_col] == 1 , value_col]
    sns.histplot(aux, fill = False,element="step", stat="density",bins = 10, color = 'red')

    aux = df.loc[df[target_col] == 0 , value_col]
    sns.histplot(aux, fill = False, element="step",stat="density",bins = 10, color = 'green')
    plt.legend(title=value_col, labels=['1', '0'], )
    plt.title('Normalized '+ value_col);
    

def df_scores(names, mean_results, std_results):

    '''Creates dataframe that display the name of the models and their comrresponding score
    ARG:
    names(list): list with model names
    results(list): list with scores of the models

    RETURNS:
    df(dataframe): dataframe with model names and their scores'''

    df_dict = {'Model_name':names,
              'Mean Score':mean_results,
              '+/-':std_results}
    df = pd.DataFrame(df_dict)

    return df

def create_base_models():

    '''Create base line models
    ARG: 
    None

    RETURNS:
    models(list): list containing base line models'''

    seed = 45

    models = []
    models.append(('LogisticRegression', LogisticRegression(random_state = seed)))
    models.append(('RandomForestClassifier', RandomForestClassifier(random_state = seed)))
    models.append(('AdaBoostClassifier', AdaBoostClassifier(random_state = seed)))
    models.append(('GradientBoosting', GradientBoostingClassifier(random_state=seed)))
    models.append(('XGBClassifier', XGBClassifier(random_state=seed)))
    models.append(('Baggging_clf', BaggingClassifier(random_state = seed) ))
    models.append(('GaussianNB',  GaussianNB()))

    return models
#================================================ evaluate_models ========================================================== 


def evaluate_models(features, target, models, learning_curve_ = False):
    ''' Evaluates models using X-Fold cross-validation. 
    Learning curve can also be plotted (optional).
    Args:
        features (dataframe) - dataset to be used for training.
        response (dataframe) - target variable
        models (list) - list of models to evaluated.
        curve (bool) - whether or not to plot learning curve.
    Returns:
        names (list) - list of models tested.
        results (list) - list of results for each model.
    '''  
    
    mean_results = []
    names = []
    std_results = []
    
    for name, model in models:
        cv_results = cross_val_score(model, 
                                    features,target,
                                    cv = 10,
                                    scoring = 'recall',
                                    n_jobs = -1 )
        
        mean, std = cv_results.mean(),cv_results.std()
        
        std_results.append(std)
        mean_results.append(mean)
        names.append(name)
        
        print()
        print('Score for {} is {} with std of {}'.format(name, mean, std))
        
        if learning_curve_:
            plot_learning_curve(features, target, model, name)
            
            
    return names, mean_results,std_results
    
#================================================ plot_learning_curve ==========================================================
    
def plot_learning_curve(features, grades, model, name):

    train_sizes, train_scores, test_scores = learning_curve(model,
                                                            features,
                                                            grades, 
                                                            cv = 10,
                                                            #scoring = 'neg_mean_squared_error',
                                                            scoring = 'recall',
                                                            n_jobs =-1,
                                                            train_sizes = np.linspace(0.1, 1.0, 10)) 
     
    plt.figure(figsize=(6,4))    
    plt.grid()

    # Create means and standard deviations of training set score
    #rmse_train_scores = np.sqrt(train_scores)
    train_mean = np.round(np.mean(train_scores, axis = 1),3)
    train_std = np.std(train_scores, axis = 1)


    # Create means and standard deviations of test set score
    #rmse_test_scores = np.sqrt(test_scores)
    test_mean = np.round(np.mean(test_scores, axis = 1),3)
    test_std = np.std(test_scores, axis = 1)
     

    #Draw curve
    plt.plot(np.linspace(.1, 1.0, 10)*100, train_mean, 'o-', color = "#111111",  label = 'training score')
    plt.plot(np.linspace(.1, 1.0, 10)*100, test_mean,'o-', color = "blue", label ='cros-validation score' )

    #Draw bands

    plt.fill_between(np.linspace(.1, 1.0, 10)*100, train_mean - train_std, train_mean + train_std, color="#DDDDDD")
    plt.fill_between(np.linspace(.1, 1.0, 10)*100, test_mean - test_std, test_mean + test_std, color="#DDDDDD")


    # Plot
    plt.title('Learning Curve for {} model'.format(name))
    plt.xlabel('% of training set')
    plt.ylabel('Recall')
    plt.xticks(np.linspace(.1, 1.0, 10)*100)
    plt.legend(loc = 'best')
    plt.tight_layout()
    plt.show()
    print()

# %% [markdown]
# * note : Need to take a look at the evaluation metrics

# %%
jupyter_settings()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# ## 0.2 Load Data

# %%
BUCKET_NAME = 'landing-zone-ds'
FILE_NAME = 'churn.csv'

# %%
df_raw = pd.read_csv(os.path.join('gs://', BUCKET_NAME, FILE_NAME))
df_raw.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1    15634602  Hargrave          619    France  Female   42       2       0.00              1          1               1        101348.88       1
# 1          2    15647311      Hill          608     Spain  Female   41       1   83807.86              1          0               1        112542.58       0
# 2          3    15619304      Onio          502    France  Female   42       8  159660.80              3          1               0        113931.57       1
# 3          4    15701354      Boni          699    France  Female   39       1       0.00              2          0               0         93826.63       0
# 4          5    15737888  Mitchell          850     Spain  Female   43       2  125510.82              1          1               1         79084.10       0

# %% [markdown]
# # 1.0 Data Description

# %% [markdown]
# * RowNumber: corresponds to the record (row) number and has no effect on the output.
# * CustomerId: contains random values and has no effect on customer leaving the bank.
# * Surname: the surname of a customer has no impact on their decision to leave the bank.
# * CreditScore: can have an effect on customer churn, since a customer with a higher credit score is less likely to leave the bank.
# * Geography: a customer’s location can affect their decision to leave the bank.
# * Gender: it’s interesting to explore whether gender plays a role in a customer leaving the bank.
# * Age: this is certainly relevant, since older customers are less likely to leave their bank than younger ones.
# * Tenure: refers to the number of years that the customer has been a client of the bank. Normally, older clients are more loyal and less likely to leave a bank.
# * Balance: also a very good indicator of customer churn, as people with a higher balance in their accounts are less likely to leave the bank compared to those with lower balances.
# * NumOfProducts: refers to the number of products that a customer has purchased through the bank.
# * HasCrCard: denotes whether or not a customer has a credit card. This column is also relevant, since people with a credit card are less likely to leave the bank.
# * IsActiveMember: active customers are less likely to leave the bank.
# * EstimatedSalary: as with balance, people with lower salaries are more likely to leave the bank compared to those with higher salaries.
# * Exited: whether or not the customer left the bank. (0=No,1=Yes)

# %% [markdown]
# ## 1.1 Data Dimension

# %%
df1 = df_raw.copy()

# %%
print('Number of Rows: {}'.format(df1.shape[0]))
print('Number of Columns: {}'.format(df1.shape[1]))
# Out:
# Number of Rows: 10000
# Number of Columns: 14

# %% [markdown]
# ## 1.2 Data Types

# %%
df1.dtypes
# Out:
# RowNumber            int64
# CustomerId           int64
# Surname             object
# CreditScore          int64
# Geography           object
# Gender              object
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %% [markdown]
# ## 1.3 Check NaN

# %%
df1.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %% [markdown]
# ## 1.4 Change Data Types

# %%
df1['CustomerId'] = df1['CustomerId'] .astype('str')

# %% [markdown]
# ## 1.5 Descriptive Statistics

# %% [markdown]
# ### 1.5.1 Numerical Attributes

# %%
num_attributes = df1.select_dtypes(include = ['int64', 'float64'])

# %%
stats_table = descriptive_sts(num_attributes)
stats_table
# Out:
#         attributes     min        max      range           mean      median           std      skew  kurtosis
# 0        RowNumber    1.00   10000.00    9999.00    5000.500000    5000.500   2886.751332  0.000000 -1.200000
# 1      CreditScore  350.00     850.00     500.00     650.528800     652.000     96.648466 -0.071607 -0.425726
# 2              Age   18.00      92.00      74.00      38.921800      37.000     10.487282  1.011320  1.395347
# 3           Tenure    0.00      10.00      10.00       5.012800       5.000      2.892030  0.010991 -1.165225
# 4          Balance    0.00  250898.09  250898.09   76485.889288   97198.540  62394.285254 -0.141109 -1.489412
# 5    NumOfProducts    1.00       4.00       3.00       1.530200       1.000      0.581625  0.745568  0.582981
# 6        HasCrCard    0.00       1.00       1.00       0.705500       1.000      0.455818 -0.901812 -1.186973
# ...

# %%
num_attributes.describe([0.05,0.25,0.50,0.75,0.90,0.95,0.99])
# Out:
#          RowNumber   CreditScore           Age        Tenure        Balance  NumOfProducts    HasCrCard  IsActiveMember  EstimatedSalary        Exited
# count  10000.00000  10000.000000  10000.000000  10000.000000   10000.000000   10000.000000  10000.00000    10000.000000     10000.000000  10000.000000
# mean    5000.50000    650.528800     38.921800      5.012800   76485.889288       1.530200      0.70550        0.515100    100090.239881      0.203700
# std     2886.89568     96.653299     10.487806      2.892174   62397.405202       0.581654      0.45584        0.499797     57510.492818      0.402769
# min        1.00000    350.000000     18.000000      0.000000       0.000000       1.000000      0.00000        0.000000        11.580000      0.000000
# 5%       500.95000    489.000000     25.000000      1.000000       0.000000       1.000000      0.00000        0.000000      9851.818500      0.000000
# ...

# %% [markdown]
# ### 1.5.2 categorical Attributes

# %%
cat_attributes = df1.select_dtypes(exclude = ['int64', 'float64'])

# %%
cat_attributes.apply(lambda x: x.unique())
# Out:
# CustomerId    [15634602, 15647311, 15619304, 15701354, 15737...
# Surname       [Hargrave, Hill, Onio, Boni, Mitchell, Chu, Ba...
# Geography                              [France, Spain, Germany]
# Gender                                           [Female, Male]
# dtype: object

# %% [markdown]
# # 2.0 Feature Engineering

# %%
df2 = df1.copy()

# %%
Image('Imgs/churn.png')

# %% [markdown]
# # 3.0 Data Filtering

# %%
df3 = df2.copy()

# %%
# As the number of clients is the same as the number of rows, we can drop this column
# RowNumber does not provide useful information (it is a index)
# We can also excluse surname
df3 = df3.drop(['RowNumber','CustomerId' ,'Surname'], axis = 1 )

# %% [markdown]
# # 4.0 EDA

# %% [markdown]
# ## 4.1 Univariate Analysis

# %%
df4 = df3.copy()

# %%
num_attributes.hist(bins = 25);
plt.tight_layout()

# %% [markdown]
# <br>
#
# **Based on the plots below I would suggest that the most relevant features that might help our model to simulate the pattern of churn are:**
# * Age
# * Geography
# * Number of Product
# * Active Member
# * Gender
#
# Looking at the plots, we can notice different patterns and this might provide relevant information for our model.

# %% [markdown]
# ### 4.1.1 Age

# %%
# age
box_dist_plots('Exited', 'Age', df4,)

# %% [markdown]
# * The mean age of the churned clients is higher than the mean of the not churned client
# * Age seemss to be a relevant feature

# %% [markdown]
# ### 4.1.2 Balance

# %%
 box_dist_plots('Exited', 'Balance', df4,)

# %% [markdown]
# ### 4.1.3 CreditScore

# %%
 box_dist_plots('Exited', 'CreditScore', df4,)

# %% [markdown]
# ### 4.1.4 Tenure

# %%
 box_dist_plots('Exited', 'Tenure', df4,)

# %% [markdown]
# ### 4.1.5 Products

# %%
 box_dist_plots('Exited', 'NumOfProducts', df4,bins =1)

# %% [markdown]
# ### 4.1.6 Salary

# %%
box_dist_plots('Exited', 'EstimatedSalary', df4)

# %% [markdown]
# Normalized plots due to unbalanced data

# %% [markdown]
# ### 4.1.7 Geography - Gender - Active Member - Credit Card

# %%
plt.subplot(4,3,1)
sns.barplot(data=df4, x="Geography", y="Exited")
plt.title('chrun rate by country')

plt.subplot(4,3,2)
aux = df3.loc[df4['Exited'] == 1]
sns.countplot( x = aux['Geography'] )
plt.title('Exited - 1');

plt.subplot(4,3,3)
aux = df3.loc[df4['Exited'] == 0]
sns.countplot( x = aux['Geography'] )
plt.title('Exited - 0');

plt.subplot(4,3,4)
sns.barplot(data=df4, x="Gender", y="Exited")
plt.title('chrun rate by Gender')

plt.subplot(4,3,5)
aux = df3.loc[df4['Exited'] == 1]
sns.countplot( x = aux['Gender'] )
plt.title('Exited - 1');

plt.subplot(4,3,6)
aux = df3.loc[df4['Exited'] == 0]
sns.countplot( x = aux['Gender'] )
plt.title('Exited - 0');

plt.subplot(4,3,7)
sns.barplot(data=df4, x="IsActiveMember", y="Exited")
plt.title('chrun rate by IsActiveMember')

plt.subplot(4,3,8)
aux = df3.loc[df4['Exited'] == 1]
sns.countplot( x = aux['IsActiveMember'] )
plt.title('Exited - 1');

plt.subplot(4,3,9)
aux = df3.loc[df4['Exited'] == 0]
sns.countplot( x = aux['IsActiveMember'] )
plt.title('Exited - 0');

plt.subplot(4,3,10)
sns.barplot(data=df4, x="HasCrCard", y="Exited")
plt.title('chrun rate by HasCrCard')

plt.subplot(4,3,11)
aux = df3.loc[df4['Exited'] == 1]
sns.countplot( x = aux['HasCrCard'] )
plt.title('Exited - 1');

plt.subplot(4,3,12)
aux = df3.loc[df4['Exited'] == 0]
sns.countplot( x = aux['HasCrCard'] )
plt.title('Exited - 0');

plt.tight_layout();

# %% [markdown]
# ### 4.1.8  Data Distribution by Country

# %%
df4.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          619    France  Female   42       2       0.00              1          1               1        101348.88       1
# 1          608     Spain  Female   41       1   83807.86              1          0               1        112542.58       0
# 2          502    France  Female   42       8  159660.80              3          1               0        113931.57       1
# 3          699    France  Female   39       1       0.00              2          0               0         93826.63       0
# 4          850     Spain  Female   43       2  125510.82              1          1               1         79084.10       0

# %% [markdown]
# ### 4.1.9 Correlation

# %%
corr = df4.corr()
corr
# Out:
#                  CreditScore       Age    Tenure   Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary    Exited
# CreditScore         1.000000 -0.003965  0.000842  0.006268       0.012238  -0.005458        0.025651        -0.001384 -0.027094
# Age                -0.003965  1.000000 -0.009997  0.028308      -0.030680  -0.011721        0.085472        -0.007201  0.285323
# Tenure              0.000842 -0.009997  1.000000 -0.012254       0.013444   0.022583       -0.028362         0.007784 -0.014001
# Balance             0.006268  0.028308 -0.012254  1.000000      -0.304180  -0.014858       -0.010084         0.012797  0.118533
# NumOfProducts       0.012238 -0.030680  0.013444 -0.304180       1.000000   0.003183        0.009612         0.014204 -0.047820
# HasCrCard          -0.005458 -0.011721  0.022583 -0.014858       0.003183   1.000000       -0.011866        -0.009933 -0.007138
# ...

# %% [markdown]
# ## 4.2 Bivariate Analysis

# %% [markdown]
# ### 4.2.1 Hipothesis: People with estimated salary lower than the estimated salary mean churn more by country

# %%
plt.subplot(2,3,1)

aux = df4[['Geography', 'Exited']].groupby('Geography').sum().reset_index()
sns.barplot(x ='Exited', y ='Geography', data = aux);
plt.title('Total');

plt.subplot(2,3,2)
aux = df4.loc[df4.EstimatedSalary > df4.EstimatedSalary.mean()]
aux = aux[['Geography', 'Exited']].groupby('Geography').sum().reset_index()
sns.barplot(x ='Exited', y ='Geography', data = aux)
plt.title('Salary greater than salary mean');

plt.subplot(2,3,3)
aux = df4.loc[df4.EstimatedSalary < df4.EstimatedSalary.mean()]
aux = aux[['Geography', 'Exited']].groupby('Geography').sum().reset_index()
sns.barplot(x ='Exited', y ='Geography', data = aux)
plt.title('Salary lower than salary mean');

# %% [markdown]
# ### 4.2.2 Hipothesis: People with estimated salary lower than the estimated salary mean churn more by Gender

# %%
plt.subplot(2,3,1)

aux = df4[['Gender', 'Exited']].groupby('Gender').sum().reset_index()
sns.barplot(x ='Exited', y ='Gender', data = aux);
plt.title('Total');

plt.subplot(2,3,2)
aux = df4.loc[df4.EstimatedSalary > df4.EstimatedSalary.mean()]
aux = aux[['Gender', 'Exited']].groupby('Gender').sum().reset_index()
sns.barplot(x ='Exited', y ='Gender', data = aux)
plt.title('Salary greater than salary mean');

plt.subplot(2,3,3)
aux = df4.loc[df4.EstimatedSalary < df4.EstimatedSalary.mean()]
aux = aux[['Gender', 'Exited']].groupby('Gender').sum().reset_index()
sns.barplot(x ='Exited', y ='Gender', data = aux)
plt.title('Salary lower than salary mean');

# %% [markdown]
# ### 4.2.3 Variables Correlation

# %%
plt.subplot(4,2,1)
aux = df4.loc[df4.Exited == 1]
sns.scatterplot(x = 'Age', y ='Balance', data = aux,hue='Exited')
plt.title('Exited')

plt.subplot(4,2,2)
aux = df4.loc[df4.Exited ==0]
sns.scatterplot(x = 'Age', y ='Balance', data = aux,hue='Exited')
plt.title('Exited')

plt.subplot(4,2,3)
aux = df4.loc[df4.Exited == 1]
sns.scatterplot(x = 'Age', y ='EstimatedSalary', data = aux,hue='Exited')
plt.title('Exited')

plt.subplot(4,2,4)
aux = df4.loc[df4.Exited ==0]
sns.scatterplot(x = 'Age', y ='EstimatedSalary', data = aux,hue='Exited')
plt.title('Exited')

plt.subplot(4,2,5)
aux = df4.loc[df4.Exited == 1]
sns.scatterplot(x = 'NumOfProducts', y ='Balance', data = aux,hue='Exited')
plt.title('Exited')

plt.subplot(4,2,6)
aux = df4.loc[df4.Exited ==0]
sns.scatterplot(x = 'NumOfProducts', y ='Balance', data = aux,hue='Exited')
plt.title('Exited')

plt.subplot(4,2,7)
aux = df4.loc[df4.Exited == 1]
sns.scatterplot(x = 'Balance', y ='EstimatedSalary', data = aux,hue='Exited')
plt.title('Exited')

plt.subplot(4,2,8)
aux = df4.loc[df4.Exited ==0]
sns.scatterplot(x = 'Balance', y ='EstimatedSalary', data = aux,hue='Exited')
plt.title('Exited')

plt.tight_layout()

# %% [markdown]
# ### 4.2.3 Feature Proportion on churn rate

# %% [markdown]
# # 5.0 Data Preparation

# %%
df5 = df4.copy()

# %% [markdown]
# ## 5.1 Standardization

# %%
from sklearn import preprocessing as pp
from sklearn import model_selection as ms
import pickle

# %%
ss = pp.StandardScaler()

df5['CreditScore'] = ss.fit_transform(df5['CreditScore'].values.reshape(-1, 1))
pickle.dump(ss, open(os.path.join('Parameters', 'CreditScore_scaler.pkl'), 'wb'))

df5['Tenure'] = ss.fit_transform(df5['Tenure'].values.reshape(-1,1))
pickle.dump(ss, open(os.path.join('Parameters', 'Tenure_scaler.pkl'), 'wb'))

df5['EstimatedSalary'] = ss.fit_transform(df5['EstimatedSalary'].values.reshape(-1,1))
pickle.dump(ss, open(os.path.join('Parameters', 'EstimatedSalary_scaler.pkl'), 'wb'))

# %% [markdown]
# ## 5.1 Min-MaxScaler

# %%
mms = pp.MinMaxScaler()

df5['Age'] = mms.fit_transform(df5['Age'].values.reshape(-1,1))
pickle.dump(ss, open(os.path.join('Parameters', 'Age_scaler.pkl'), 'wb'))

df5['Balance'] = mms.fit_transform(df5['Balance'].values.reshape(-1,1))
pickle.dump(ss, open(os.path.join('Parameters', 'Balance_scaler.pkl'), 'wb'))

# %% [markdown]
# ## 5.2 Encoding

# %%
#frequency encoding
fe_geography = df5.groupby('Geography').size() / len(df5)
df5.loc[:,'Geography'] = df5['Geography'].map(fe_geography)

# Tearget Encoder
target_encoder_gender = df5.groupby('Gender')['Exited'].mean()
df5.loc[:,'Gender'] = df5['Gender'].map(target_encoder_gender)

# %% [markdown]
# # 6.0 Feature Selection

# %%
df6 = df5.copy()

# %%
cols_selected = list(df6.columns)

# %% [markdown]
# ## 6.1 Split dataframe into training and test set

# %%
X = df6.drop('Exited', axis = 1).copy()
y = df6['Exited'].copy()

X_train,X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 10, shuffle = True, stratify = y )

# %%
total_churn = y_train.sum()
churn_ratio = total_churn / len(y_train)
churn_ratio
# Out:
# 0.20375

# %% [markdown]
# # 7.0 Machine Learning

# %%
models = create_base_models()
names, mean_results,std_results= evaluate_models(X_train, y_train, models, learning_curve_=True)
models_df = df_scores(names,mean_results,std_results)
# Out:
# Score for LogisticRegression is 0.16809815950920245 with std of 0.0263446755258698
# Score for RandomForestClassifier is 0.44539877300613506 with std of 0.04024839132970975
# Score for AdaBoostClassifier is 0.4625766871165645 with std of 0.046171503612826445
# Score for GradientBoosting is 0.46196319018404913 with std of 0.03890267205518451
# Score for XGBClassifier is 0.48588957055214727 with std of 0.03125825571253251
# Score for Baggging_clf is 0.4257668711656442 with std of 0.03450886162067542
# Score for GaussianNB is 0.2595092024539877 with std of 0.03223633044274762

# %%
models_df
# Out:
#                Model_name  Mean Score       +/-
# 0      LogisticRegression    0.168098  0.026345
# 1  RandomForestClassifier    0.445399  0.040248
# 2      AdaBoostClassifier    0.462577  0.046172
# 3        GradientBoosting    0.461963  0.038903
# 4           XGBClassifier    0.485890  0.031258
# 5            Baggging_clf    0.425767  0.034509
# 6              GaussianNB    0.259509  0.032236

# %% [markdown]
# ## 7.1 Choosing  Models

# %%
from sklearn.model_selection import cross_val_predict
from sklearn.metrics         import recall_score

# %%
rf = RandomForestClassifier()
adboost = AdaBoostClassifier()
gboost = GradientBoostingClassifier()
xgb = BaggingClassifier()

models = [rf, adboost,gboost,xgb]
model_names = ['rf', 'adboost', 'gboost','xgb']
scoring = 'recall'

y_probas = []
thresholds = np.arange(0.5, 1., .1)
recall_scores_ = []
for model, name in zip(models, model_names):
    y_proba = cross_val_predict(model, X_train, y=y_train, cv=10, n_jobs=-1, method='predict_proba')[:, 1]
    y_probas.append(y_proba)
    print(f'Recalls for {name}:')
    scores = []
    for threshold in thresholds:
        y_pred = (y_proba >= threshold).astype(int)
        score = recall_score(y_train, y_pred)
        scores.append(score)
        print(f'Threshold {threshold:.1f}: {score:.3f}')
    print()
    recall_scores_.append(scores)
# Out:
# Recalls for rf:
# Threshold 0.5: 0.460
# Threshold 0.6: 0.379
# Threshold 0.7: 0.298
# Threshold 0.8: 0.220
# Threshold 0.9: 0.092
#
# Recalls for adboost:
# Threshold 0.5: 0.463
# Threshold 0.6: 0.029
# Threshold 0.7: 0.001
# Threshold 0.8: 0.000
# Threshold 0.9: 0.000
#
# Recalls for gboost:
# Threshold 0.5: 0.462
# Threshold 0.6: 0.387
# Threshold 0.7: 0.332
# Threshold 0.8: 0.248
# Threshold 0.9: 0.144
#
# Recalls for xgb:
# Threshold 0.5: 0.521
# Threshold 0.6: 0.433
# Threshold 0.7: 0.358
# Threshold 0.8: 0.295
# Threshold 0.9: 0.221

# %% [markdown]
# ## 7.2 Model Performance

# %%
import scikitplot as skplt

# %%
threshold = .7
for y_proba, model_name in zip(y_probas, model_names):
    ypred = (y_proba >= threshold).astype(int)
    skplt.metrics.plot_confusion_matrix(y_train, ypred, labels=None, true_labels=None,
                                        pred_labels=None, title=model_name, normalize=False,
                                        hide_zeros=False, hide_counts=False, x_tick_rotation=0,
                                        ax=None, figsize=(8,4), cmap='Blues',
                                        title_fontsize='large', text_fontsize='medium')

# %%
rates = []
lifts = []
gains = []
step = .1

def calculate_ones_rate(y, y_pred, step=0.1):
    aux_lift = pd.DataFrame()
    aux_lift['true'] = y
    aux_lift['pred'] = y_pred
    aux_lift.sort_values('pred', ascending=True, inplace=True)

    x_val = np.arange(0, 1, step)
    y_val = []
    for x in x_val:
        row_slice_min = int(np.ceil(x * aux_lift.shape[0])) 
        row_slice_max = int(np.ceil((x+step) * aux_lift.shape[0])) 
        sliced_dataframe = aux_lift.iloc[row_slice_min:row_slice_max, :]
        ratio_ones = sliced_dataframe['true'].sum() / sliced_dataframe.shape[0]
        y_val.append(ratio_ones)

    return y_val

for y_proba in y_probas[:2]:
    rates.append(calculate_ones_rate(y_train, y_proba, step=step))

# %%
def calculate_gain(y, y_pred, step=0.1):
    aux_lift = pd.DataFrame()
    aux_lift['true'] = y
    aux_lift['pred'] = y_pred
    aux_lift.sort_values('pred', ascending=False, inplace=True)

    x_val = np.arange(step, step + 1, step)
    num_ones = aux_lift['true'].sum()
    N = len(aux_lift)
    ratio_ones = num_ones / N

    gains = [0] # first element
    for x in x_val:
        num_data = int(np.ceil(x * N)) 
        data_here = aux_lift.iloc[:num_data, :]
        num_ones_here = data_here['true'].sum()
        ratio_ones_here = num_ones_here / num_data
        gains.append(num_ones_here / num_ones)
           
    return  gains

# %%
calculate_gain(y_train, y_proba, step=0.1)
# Out:
# [0.3901840490797546,
#  0.5828220858895705,
#  0.7214723926380369,
#  0.811042944785276,
#  0.8705521472392638,
#  0.9220858895705522,
#  0.9558282208588957,
#  0.9791411042944785,
#  0.9883435582822085,
#  1.0]

# %% [markdown]
# # 8.0 Hyperparameter Fine Tune

# %% [markdown]
# # 9.0 Error Interpreration

# %% [markdown]
# # 10.0 Deploy Model
